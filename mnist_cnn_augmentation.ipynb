# %% [markdown]
# <a href="https://colab.research.google.com/github/marcinwolter/DeepLearning_2020/blob/main/mnist_cnn_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''Trains a simple deep NN on the MNIST dataset.

Gets to 99.6% test accuracy after 40 epochs
(there is *a lot* of margin for parameter tuning).
2 seconds per epoch on a K520 GPU.
'''

from __future__ import print_function

import matplotlib.pyplot as plt
import numpy as np

import keras
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from keras.optimizers import RMSprop, Adam, Adadelta

from keras.utils.vis_utils import plot_model
from IPython.display import Image 

from keras.callbacks import EarlyStopping

#augmentation
from keras.preprocessing.image import ImageDataGenerator

batch_size = 128
num_classes = 10
epochs = 100

# input image dimensions
img_rows, img_cols = 28, 28

# the data, split between train and test sets
(x_train, y_train0), (x_test, y_test0) = mnist.load_data()

if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], 1, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], 1, img_rows, img_cols)
    input_shape = (1, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, 1)
    input_shape = (img_rows, img_cols, 1)



x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_test /= 255
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')

# convert class vectors to binary class matrices
y_train = keras.utils.to_categorical(y_train0, num_classes)
y_test = keras.utils.to_categorical(y_test0, num_classes)
# Out:
# 60000 train samples
# 10000 test samples

# %% [markdown]
# # **Reduce the dataset size**

# %%
N_TRAIN_EXAMPLES = 1000 #3000
N_TEST_EXAMPLES = 10000

x_train = x_train[:N_TRAIN_EXAMPLES]
x_test = x_test[:N_TEST_EXAMPLES]
y_train = y_train[:N_TRAIN_EXAMPLES]
y_test = y_test[:N_TEST_EXAMPLES]

# %%
# CREATE MORE IMAGES VIA DATA AUGMENTATION

datagen = ImageDataGenerator( 
        rotation_range=20,  
        zoom_range = 0.20,  
        width_shift_range=0.2,  
        height_shift_range=0.2)
'''
datagen = ImageDataGenerator( 
        rotation_range=0,  
        zoom_range = 0.0,  
        width_shift_range=0.0, 
        height_shift_range=0.0)
'''
# Out:
# '\ndatagen = ImageDataGenerator( \n        rotation_range=0,  \n        zoom_range = 0.0,  \n        width_shift_range=0.0, \n        height_shift_range=0.0)\n'

# %%
# see augmentation example (single digit)
fig = plt.figure(figsize=(10, 10))
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

for i in range(0, 100):
    for X_train, Y_train in datagen.flow(x_train[2:3], y_train[2:3], batch_size=1, shuffle=False):
         plt.subplot(10,10,i+1)
         plt.imshow(X_train[0].reshape((img_rows, img_cols)), cmap=plt.cm.binary, interpolation='nearest')
         plt.axis('off')
         break

plt.show()

# %%
#visualize the digits

fig = plt.figure(figsize=(10, 10))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)

# generate augmented plot
X_train, Y_train = datagen.flow(x_train,y_train, batch_size=100).next()
for i in range(100):
    ax = fig.add_subplot(10, 10, i + 1, xticks=[], yticks=[])
    ax.imshow(X_train[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')
    # label the image with the target value
    ax.text(0, 7, str(np.argmax(Y_train[i])))

# %%
# Our old fully connected (dense) network
#model = Sequential()
#model.add(Dense(512, activation='relu', input_shape=(784,)))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(512, activation='relu'))
#model.add(Dropout(0.2))
#model.add(Dense(num_classes, activation='softmax'))

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Conv2D(64, kernel_size=(3, 3),
                 activation='relu',
                 input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))



model.summary()
# Out:
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_36 (Conv2D)           (None, 26, 26, 32)        320
# _________________________________________________________________
# conv2d_37 (Conv2D)           (None, 24, 24, 64)        18496
# _________________________________________________________________
# max_pooling2d_18 (MaxPooling (None, 12, 12, 64)        0
# _________________________________________________________________
# dropout_27 (Dropout)         (None, 12, 12, 64)        0
# _________________________________________________________________
# conv2d_38 (Conv2D)           (None, 10, 10, 64)        36928
# _________________________________________________________________
# conv2d_39 (Conv2D)           (None, 8, 8, 64)          36928
# _________________________________________________________________
# max_pooling2d_19 (MaxPooling (None, 4, 4, 64)          0
# _________________________________________________________________
# dropout_28 (Dropout)         (None, 4, 4, 64)          0
# _________________________________________________________________
# flatten_9 (Flatten)          (None, 1024)              0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               131200
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 225,162
# Trainable params: 225,162
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
Image('model_plot.png')

# %%
model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

es = EarlyStopping(monitor = 'val_accuracy', patience = 12, verbose=1)

history = model.fit(datagen.flow(x_train, y_train, batch_size=batch_size),
                    batch_size=batch_size,
                    epochs=epochs,
                    verbose=1,
                    validation_data=(x_test, y_test),
                    callbacks = [es])
# Out:
# Epoch 1/100
# 8/8 [==============================] - 1s 85ms/step - loss: 2.3066 - accuracy: 0.1100 - val_loss: 2.2828 - val_accuracy: 0.2446
# Epoch 2/100
# 8/8 [==============================] - 1s 65ms/step - loss: 2.2925 - accuracy: 0.1300 - val_loss: 2.2435 - val_accuracy: 0.2658
# Epoch 3/100
# 8/8 [==============================] - 1s 69ms/step - loss: 2.2729 - accuracy: 0.1480 - val_loss: 2.1377 - val_accuracy: 0.4587
# Epoch 4/100
# 8/8 [==============================] - 1s 65ms/step - loss: 2.2186 - accuracy: 0.1890 - val_loss: 1.8436 - val_accuracy: 0.5004
# Epoch 5/100
# 8/8 [==============================] - 1s 63ms/step - loss: 2.1158 - accuracy: 0.2290 - val_loss: 1.5345 - val_accuracy: 0.6036
# Epoch 6/100
# 8/8 [==============================] - 1s 65ms/step - loss: 1.9001 - accuracy: 0.3360 - val_loss: 1.0921 - val_accuracy: 0.7378
# Epoch 7/100
# 8/8 [==============================] - 1s 67ms/step - loss: 1.7999 - accuracy: 0.3720 - val_loss: 1.0261 - val_accuracy: 0.7647
# Epoch 8/100
# 8/8 [==============================] - 1s 64ms/step - loss: 1.6841 - accuracy: 0.4200 - val_loss: 0.8952 - val_accuracy: 0.7904
# Epoch 9/100
# 8/8 [==============================] - 1s 63ms/step - loss: 1.5133 - accuracy: 0.4880 - val_loss: 0.6934 - val_accuracy: 0.8429
# Epoch 10/100
# 8/8 [==============================] - 1s 69ms/step - loss: 1.4599 - accuracy: 0.5050 - val_loss: 0.6789 - val_accuracy: 0.8421
# Epoch 11/100
# 8/8 [==============================] - 1s 65ms/step - loss: 1.3182 - accuracy: 0.5620 - val_loss: 0.5765 - val_accuracy: 0.8496
# Epoch 12/100
# 8/8 [==============================] - 1s 65ms/step - loss: 1.3597 - accuracy: 0.5470 - val_loss: 0.5376 - val_accuracy: 0.8801
# Epoch 13/100
# 8/8 [==============================] - 1s 64ms/step - loss: 1.1928 - accuracy: 0.5930 - val_loss: 0.4758 - val_accuracy: 0.8848
# Epoch 14/100
# 8/8 [==============================] - 1s 63ms/step - loss: 1.1391 - accuracy: 0.6260 - val_loss: 0.4402 - val_accuracy: 0.8937
# Epoch 15/100
# 8/8 [==============================] - 1s 66ms/step - loss: 1.1081 - accuracy: 0.6260 - val_loss: 0.4454 - val_accuracy: 0.8790
# Epoch 16/100
# 8/8 [==============================] - 1s 65ms/step - loss: 1.0779 - accuracy: 0.6530 - val_loss: 0.4282 - val_accuracy: 0.8903
# Epoch 17/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.9631 - accuracy: 0.6700 - val_loss: 0.3419 - val_accuracy: 0.9116
# Epoch 18/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.9311 - accuracy: 0.6940 - val_loss: 0.3162 - val_accuracy: 0.9118
# Epoch 19/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.9351 - accuracy: 0.6880 - val_loss: 0.3315 - val_accuracy: 0.9188
# Epoch 20/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.8432 - accuracy: 0.7200 - val_loss: 0.2839 - val_accuracy: 0.9250
# Epoch 21/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.8616 - accuracy: 0.7190 - val_loss: 0.2496 - val_accuracy: 0.9299
# Epoch 22/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.7835 - accuracy: 0.7460 - val_loss: 0.2557 - val_accuracy: 0.9285
# Epoch 23/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.7614 - accuracy: 0.7570 - val_loss: 0.2528 - val_accuracy: 0.9277
# Epoch 24/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.6827 - accuracy: 0.7800 - val_loss: 0.2350 - val_accuracy: 0.9301
# Epoch 25/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.6958 - accuracy: 0.7860 - val_loss: 0.2062 - val_accuracy: 0.9421
# Epoch 26/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.6919 - accuracy: 0.7910 - val_loss: 0.2104 - val_accuracy: 0.9415
# Epoch 27/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.6972 - accuracy: 0.7770 - val_loss: 0.1893 - val_accuracy: 0.9496
# Epoch 28/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.6620 - accuracy: 0.7990 - val_loss: 0.1742 - val_accuracy: 0.9509
# Epoch 29/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.6942 - accuracy: 0.7810 - val_loss: 0.1732 - val_accuracy: 0.9507
# Epoch 30/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.6887 - accuracy: 0.7830 - val_loss: 0.1931 - val_accuracy: 0.9463
# Epoch 31/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.6597 - accuracy: 0.7870 - val_loss: 0.2125 - val_accuracy: 0.9426
# Epoch 32/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.6297 - accuracy: 0.8050 - val_loss: 0.1862 - val_accuracy: 0.9417
# Epoch 33/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.6134 - accuracy: 0.8160 - val_loss: 0.1846 - val_accuracy: 0.9459
# Epoch 34/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.5698 - accuracy: 0.8190 - val_loss: 0.1559 - val_accuracy: 0.9557
# Epoch 35/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.5579 - accuracy: 0.8380 - val_loss: 0.1992 - val_accuracy: 0.9408
# Epoch 36/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.5592 - accuracy: 0.8260 - val_loss: 0.1920 - val_accuracy: 0.9434
# Epoch 37/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.5677 - accuracy: 0.8190 - val_loss: 0.1804 - val_accuracy: 0.9496
# Epoch 38/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.5203 - accuracy: 0.8430 - val_loss: 0.1520 - val_accuracy: 0.9571
# Epoch 39/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.5274 - accuracy: 0.8440 - val_loss: 0.1484 - val_accuracy: 0.9551
# Epoch 40/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.5332 - accuracy: 0.8410 - val_loss: 0.1736 - val_accuracy: 0.9509
# Epoch 41/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.5131 - accuracy: 0.8420 - val_loss: 0.1599 - val_accuracy: 0.9524
# Epoch 42/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.5032 - accuracy: 0.8450 - val_loss: 0.1552 - val_accuracy: 0.9540
# Epoch 43/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.4630 - accuracy: 0.8710 - val_loss: 0.1468 - val_accuracy: 0.9542
# Epoch 44/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.4749 - accuracy: 0.8540 - val_loss: 0.1302 - val_accuracy: 0.9604
# Epoch 45/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.4389 - accuracy: 0.8710 - val_loss: 0.1277 - val_accuracy: 0.9605
# Epoch 46/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.4351 - accuracy: 0.8710 - val_loss: 0.1192 - val_accuracy: 0.9630
# Epoch 47/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.4160 - accuracy: 0.8780 - val_loss: 0.1388 - val_accuracy: 0.9581
# Epoch 48/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.4503 - accuracy: 0.8660 - val_loss: 0.1180 - val_accuracy: 0.9625
# Epoch 49/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.4080 - accuracy: 0.8740 - val_loss: 0.1433 - val_accuracy: 0.9526
# Epoch 50/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.4237 - accuracy: 0.8650 - val_loss: 0.1185 - val_accuracy: 0.9647
# Epoch 51/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.3999 - accuracy: 0.8880 - val_loss: 0.1445 - val_accuracy: 0.9553
# Epoch 52/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.4005 - accuracy: 0.8810 - val_loss: 0.1356 - val_accuracy: 0.9582
# Epoch 53/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.4025 - accuracy: 0.8740 - val_loss: 0.1123 - val_accuracy: 0.9653
# Epoch 54/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.4629 - accuracy: 0.8690 - val_loss: 0.1163 - val_accuracy: 0.9660
# Epoch 55/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3938 - accuracy: 0.8760 - val_loss: 0.1376 - val_accuracy: 0.9573
# Epoch 56/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.4095 - accuracy: 0.8830 - val_loss: 0.1231 - val_accuracy: 0.9613
# Epoch 57/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3686 - accuracy: 0.8910 - val_loss: 0.1056 - val_accuracy: 0.9669
# Epoch 58/100
# 8/8 [==============================] - 1s 67ms/step - loss: 0.3847 - accuracy: 0.8870 - val_loss: 0.1180 - val_accuracy: 0.9638
# Epoch 59/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.4541 - accuracy: 0.8720 - val_loss: 0.1616 - val_accuracy: 0.9508
# Epoch 60/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3571 - accuracy: 0.8890 - val_loss: 0.0986 - val_accuracy: 0.9687
# Epoch 61/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.3539 - accuracy: 0.8830 - val_loss: 0.1145 - val_accuracy: 0.9661
# Epoch 62/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3835 - accuracy: 0.8780 - val_loss: 0.0951 - val_accuracy: 0.9706
# Epoch 63/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3450 - accuracy: 0.8920 - val_loss: 0.1270 - val_accuracy: 0.9630
# Epoch 64/100
# 8/8 [==============================] - 0s 62ms/step - loss: 0.3862 - accuracy: 0.8920 - val_loss: 0.1042 - val_accuracy: 0.9669
# Epoch 65/100
# 8/8 [==============================] - 0s 61ms/step - loss: 0.3255 - accuracy: 0.8920 - val_loss: 0.0971 - val_accuracy: 0.9694
# Epoch 66/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3472 - accuracy: 0.9020 - val_loss: 0.1081 - val_accuracy: 0.9670
# Epoch 67/100
# 8/8 [==============================] - 1s 70ms/step - loss: 0.3389 - accuracy: 0.8970 - val_loss: 0.1123 - val_accuracy: 0.9633
# Epoch 68/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3167 - accuracy: 0.9140 - val_loss: 0.1020 - val_accuracy: 0.9680
# Epoch 69/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.3274 - accuracy: 0.9070 - val_loss: 0.0973 - val_accuracy: 0.9675
# Epoch 70/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3129 - accuracy: 0.9020 - val_loss: 0.0858 - val_accuracy: 0.9731
# Epoch 71/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.3212 - accuracy: 0.9030 - val_loss: 0.0904 - val_accuracy: 0.9709
# Epoch 72/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.3443 - accuracy: 0.8970 - val_loss: 0.0948 - val_accuracy: 0.9704
# Epoch 73/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.3427 - accuracy: 0.9020 - val_loss: 0.1005 - val_accuracy: 0.9679
# Epoch 74/100
# 8/8 [==============================] - 1s 69ms/step - loss: 0.2829 - accuracy: 0.9140 - val_loss: 0.1185 - val_accuracy: 0.9653
# Epoch 75/100
# 8/8 [==============================] - 1s 65ms/step - loss: 0.3443 - accuracy: 0.8960 - val_loss: 0.0941 - val_accuracy: 0.9699
# Epoch 76/100
# 8/8 [==============================] - 1s 69ms/step - loss: 0.3084 - accuracy: 0.9140 - val_loss: 0.1109 - val_accuracy: 0.9661
# Epoch 77/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.3121 - accuracy: 0.9070 - val_loss: 0.0990 - val_accuracy: 0.9708
# Epoch 78/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.2624 - accuracy: 0.9150 - val_loss: 0.0917 - val_accuracy: 0.9724
# Epoch 79/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2771 - accuracy: 0.9120 - val_loss: 0.0960 - val_accuracy: 0.9713
# Epoch 80/100
# 8/8 [==============================] - 1s 63ms/step - loss: 0.3331 - accuracy: 0.8950 - val_loss: 0.0920 - val_accuracy: 0.9689
# Epoch 81/100
# 8/8 [==============================] - 1s 66ms/step - loss: 0.3188 - accuracy: 0.9120 - val_loss: 0.0914 - val_accuracy: 0.9714
# Epoch 82/100
# 8/8 [==============================] - 1s 64ms/step - loss: 0.2840 - accuracy: 0.9150 - val_loss: 0.1405 - val_accuracy: 0.9586
# Epoch 00082: early stopping

# %%
# Plots for training and testing process: loss and accuracy

n_epochs = len(history.history['loss'])

plt.figure(0)
plt.plot(history.history['accuracy'],'r')
plt.plot(history.history['val_accuracy'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Accuracy")
plt.title("Training Cat_Accuracy vs Validation Cat_Accuracy")
plt.legend(['train','validation'])

# %%
plt.figure(1)
plt.plot(history.history['loss'],'r')
plt.plot(history.history['val_loss'],'g')
plt.xticks(np.arange(0, n_epochs, 10.0))
plt.rcParams['figure.figsize'] = (8, 6)
plt.xlabel("Num of Epochs")
plt.ylabel("Loss")
plt.title("Training Loss vs Validation Loss")
plt.legend(['train','validation'])
plt.show()

# %%
score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Test loss: 0.14047087728977203
# Test accuracy: 0.9585999846458435

# %%
# evaluate loaded model
scores_train = model.evaluate(x_train, y_train, verbose=0)
scores_test  = model.evaluate(x_test,  y_test,  verbose=0)

print("Accuracy Train: %.2f%% , Test: %.2f%% " % (scores_train[1]*100, scores_test[1]*100 ))
# Out:
# Accuracy Train: 98.10% , Test: 95.86%

# %%
# Confusion matrix result

from sklearn.metrics import classification_report, confusion_matrix
Y_pred = model.predict(x_test, verbose=2)

y_pred = np.argmax(Y_pred, axis=1)

y_test2 = np.argmax(y_test, axis=1)



#confusion matrix
cm = confusion_matrix(np.argmax(y_test,axis=1),y_pred)
print(cm)
# Out:
# 313/313 - 0s
# [[ 939    0    4    0    1    0    4    1   18   13]
#  [   0 1071    5    1    1    5   12    7   32    1]
#  [   1    0 1012    8    0    0    1    1    9    0]
#  [   0    0    3  992    0    6    0    3    5    1]
#  [   2    0    0    0  893    0   13    1   10   63]
#  [   0    0    0    5    0  870    2    1   14    0]
#  [   2    0    1    0    0    2  937    0   16    0]
#  [   1    1   44   22    2    0    0  927    4   27]
#  [   0    0    3    1    0    0    0    0  963    7]
#  [   2    0    0    5    0   10    1    0    9  982]]

# %%
# Visualizing of confusion matrix
import seaborn as sn
import pandas  as pd


df_cm = pd.DataFrame(cm, range(10),range(10))
#                     range(num_classes),
#                  range(num_classes))
#plt.figure(figsize = (10,7))
plt.figure(2,figsize = (15,15) )
sn.set(font_scale=1.4) #for label size
sn.heatmap(df_cm, annot=True,annot_kws={"size": 12})# font size
plt.show()

# %%
# use the model to predict the labels of the test data
predicted = model.predict(x_test)
expected = y_test0



# Plot the prediction
fig = plt.figure(figsize=(20, 20))  # figure size in inches
fig.subplots_adjust(left=0, right=1, bottom=0, top=1, hspace=0.05, wspace=0.05)


# plot the digits: each image is 28x28 pixels
for i in range(400):
    ax = fig.add_subplot(20, 20, i + 1, xticks=[], yticks=[])
    ax.imshow(x_test[i].reshape(img_rows, img_cols), cmap=plt.cm.binary, interpolation='nearest')

    # label the image with the target value
    if np.argmax(predicted[i]) == expected[i]:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='green')
    else:
        ax.text(0, 7, str(expected[i])+" "+str(np.argmax(predicted[i])), color='red')

# %%
# Creates the graph.png file

! pip3 install keras-visualizer
from keras_visualizer import visualizer  

#create the graph.png image
visualizer(model=model, view=True, format='png', filename='graph')

#show the graph
import matplotlib.image as mpimg
img = mpimg.imread('graph.png')
imgplot = plt.imshow(img,)
plt.show()
# Out:
# Requirement already satisfied: keras-visualizer in /usr/local/lib/python3.6/dist-packages (2.4)
